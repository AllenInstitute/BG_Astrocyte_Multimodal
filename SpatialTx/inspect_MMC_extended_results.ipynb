# %%
# %load_ext autoreload
# %autoreload 2

# %%
import json

# %%
with open("/data/mapping_output/extended_results/1304618482_mmc_extended_results.json", "r") as f:
    extended_results = json.load(f)

extended_results.keys()
# Out:
# dict_keys(['results', 'marker_genes', 'taxonomy_tree', 'n_unmapped_genes', 'config', 'log', 'metadata'])

# %%
extended_results['results']
# Out:
# [{'cluster_id': {'assignment': 'Human-1',
#    'bootstrapping_probability': 1.0,
#    'aggregate_probability': 1.0,
#    'avg_correlation': 0.36047724654510865,
#    'runner_up_assignment': [],
#    'runner_up_correlation': [],
#    'runner_up_probability': [],
#    'directly_assigned': True},
#   'Neighborhood': {'assignment': 'Nonneuron',
#    'bootstrapping_probability': 1.0,
#    'aggregate_probability': 1.0,
#    'avg_correlation': 0.36047724654510865,
#    'runner_up_assignment': [],
#    'runner_up_correlation': [],
#    'runner_up_probability': [],
#    'directly_assigned': False},
#   'Class': {'assignment': 'OPC-Oligo',
#    'bootstrapping_probability': 1.0,
#    'aggregate_probability': 1.0,
#    'avg_correlation': 0.36047724654510865,
#    'runner_up_assignment': [],
#    'runner_up_correlation': [],
#    'runner_up_probability': [],
#    'directly_assigned': False},
#   'Subclass': {'assignment': 'Oligodendrocyte',
#    'bootstrapping_probability': 1.0,
# ...

# %%
extended_results['taxonomy_tree']
# Out:
# {'Neighborhood': {'Nonneuron': ['Astro-Epen',
#    'Immune',
#    'OPC-Oligo',
#    'Vascular'],
#   'Subpallium GABA': ['CN CGE GABA',
#    'CN LGE GABA',
#    'CN MGE GABA',
#    'Cx GABA',
#    'F M GABA'],
#   'Adjacent': ['Adjacent'],
#   'Glut Sero Dopa': ['F M Glut', 'M Dopa'],
#   'Subpallium GABA-Glut': ['CN GABA-Glut']},
#  'Class': {'Vascular': ['Endo', 'Pericyte', 'SMC', 'VLMC'],
#   'OPC-Oligo': ['COP', 'OPC', 'Oligodendrocyte'],
#   'Immune': ['Lymphocyte', 'Macrophage', 'Microglia', 'Monocyte'],
#   'Astro-Epen': ['Astrocyte', 'Ependymal'],
#   'CN LGE GABA': ['CN MEIS2 GABA',
#    'OT Granular GABA',
#    'STR D1 MSN',
#    'STR D2 MSN',
#    'STR Hybrid MSN'],
#   'CN MGE GABA': ['CN Cholinergic GABA',
#    'CN LAMP5-LHX6 GABA',
#    'CN ST18 GABA',
#    'STR RSPO2 GABA',
#    'STR SST GABA',
#    'STR SST-CHODL GABA'],
#   'F M GABA': ['CN LHX8 GABA',
#    'CN ONECUT1 GABA',
#    'F GABA',
#    'F M GATA3 GABA',
#    'SN PAX7 GABA'],
# ...
